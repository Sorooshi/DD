# %%
import sys
import shap 
import pickle
import sklearn 
import numpy as np
import pandas as pd
import seaborn  as sns
from pathlib import Path
import matplotlib.pyplot as plt
from types import SimpleNamespace

# %%
sys.path.append("../")

from dd_package.data.dyslexia_data import DyslexiaData
from dd_package.data.preprocess import preprocess_data

from dd_package.models.regression_estimators import RegressionEstimators

from dd_package.common.utils import save_a_dict, load_a_dict, print_the_evaluated_results

from dd_package.data.preprocess import minmax_standardizer_

# %%
configs = {
    "models_path": Path("/home/soroosh/Programmes/DD/Models"),
    "results_path": Path("/home/soroosh/Programmes/DD/Results"),
    "figures_path": Path("/home/soroosh/Programmes/DD/Figures"),
    "params_path": Path("/home/soroosh/Programmes/DD//Params"),
    "n_repeats": 10,
    "n_splits": 5,
}

configs = SimpleNamespace(**configs)

# %%
data_name="dd_fix_demo"

estimator_name = "mlp_cls"
to_shuffle = True
to_exclude_at_risk = 0

# %%
specifier = data_name + "-" + estimator_name + \
"--shuffled:" + str(to_shuffle) + \
"--exclude at risk:" + str(to_exclude_at_risk)

# %%
configs.specifier = specifier
configs.data_name = data_name

# %%
configs.specifier
# Out:
# 'dd_fix_demo-mlp_cls--shuffled:True--exclude at risk:0'

# %% [markdown]
# ## Load Data

# %%
dd = DyslexiaData(path="../../datasets/", n_repeats=5)

# %%
if data_name == "dd_demo":
    # dict of dicts, s.t each dict contains pd.df of a class, e.g normal
    _ = dd.get_demo_datasets()  # demos and phonological (which is initially part of demo)
    demo_phono = dd.concat_classes_demo()

    # The optimize way to exclude at-risk class
    if to_exclude_at_risk == 1:
        to_exclude_at_risk = True
        demo_phono = demo_phono.loc[demo_phono.Group != 2]

    df_data_to_use = demo_phono.loc[:, [
                                           'Group', 'SubjectID', 'Sex', 'Grade', 'Age', 'IQ', 'Reading_speed',
                                       ]]
    c_features = ['Sex', 'Grade', ]
    indicators = ['SubjectID', ]
    targets = ["Group", "Reading_speed", ]

elif data_name == "dd_fix_demo":
    # dict of dicts, s.t each dict contains pd.df of a class, e.g normal
    _ = dd.get_demo_datasets()  # demos
    _ = dd.get_fix_datasets()  # fixes

    # concatenate pd.dfs to a pd.df
    fix = dd.concat_classes_fix()
    demo_phono = dd.concat_classes_demo()

    # The optimize way to exclude at-risk class
    if to_exclude_at_risk == 1:
        to_exclude_at_risk = True
        fix = fix.loc[fix.Group != 2]
        demo_phono = demo_phono.loc[demo_phono.Group != 2]

    fix_demo = dd.concat_dfs(
        df1=fix,
        df2=demo_phono,
        features1=fix.columns,
        features2=[
            "Sex", "Grade", "Age", "IQ", "Reading_speed",
        ],
    )

    df_data_to_use = fix_demo
    c_features = ['Sex', 'Grade', ]
    indicators = [
        'SubjectID', 'Sentence_ID', 'Word_Number',
    ]

    targets = ["Group", "Reading_speed", ]
    
elif data_name == "dd_fix":

    # dict of dicts, s.t each dict contains pd.df of a class, e.g normal
    _ = dd.get_fix_datasets()  # fixes
    # concatenate pd.dfs to a pd.df
    fix = dd.concat_classes_fix()

    # The optimize way to exclude at-risk class
    if to_exclude_at_risk == 1:
        to_exclude_at_risk = True
        fix = fix.loc[fix.Group != 2]

    df_data_to_use = fix
    c_features = None
    indicators = [
        'SubjectID', 'Sentence_ID', 'Word_Number',
    ]

    targets = ["Group", ]
    
    
    
    


x_org, y_org = dd.get_onehot_features_targets(
    data=df_data_to_use,
    c_features=c_features,
    indicators=indicators,
    targets=targets,
)



x = preprocess_data(x=x_org, pp="mm")  # only x is standardized




features = dd.features
features
# Out:
# Loading Demo data:
#   dyslexia (72, 9)
#   norm (213, 9)
#   risk (22, 9)
#
# Loading Fixation report data:
#   dyslexia (59770, 7)
#   norm (139507, 7)
#   risk (26073, 7)
#
# pre-processing: mm
# Preprocessed data shape: (225350, 13)
# ['FIX_DURATION',
#  'FIX_Y',
#  'FIX_X',
#  'Grade_5',
#  'Age',
#  'Grade_1',
#  'Sex_1',
#  'Grade_4',
#  'IQ',
#  'Sex_2',
#  'Grade_3',
#  'Grade_2',
#  'Grade_6']

# %%
# df_data_to_use.head()

# %%
# x_org.head()

# %%
# y_org.head()

# %%
data_name
# Out:
# 'dd_fix_demo'

# %%
class_names = ['Norm', 'At-risk', 'Dyslexic']

# %% [markdown]
# ## Load new test data

# %%
data_sets_xls = pd.ExcelFile("../../datasets/Fix_Demo_test_data_1_G.xlsx")
print(data_sets_xls.sheet_names)
# Out:
# ['demography_test', 'fixations_test', 'ground_truth']

# %%
print("Loading Demo data: ")
tmp_demo = pd.read_excel(data_sets_xls, 'ground_truth',)
tmp_demo = dd._remove_missing_data(df=tmp_demo)


tmp_demo.replace(
    to_replace={"Sex": {"fem": 1, "f": 1, "masc": 2, "m": 2}},
    inplace=True,
)


tmp_demo = tmp_demo.astype({
    "SubjectID": str,
    "Sex": int,
    "Grade": int,
    "Age": int,
    "IQ": int,
    "Group": int,
})


demo_new = tmp_demo.sort_values(by=["SubjectID"]).dropna()

print(" ", demo_new.shape)
print(" ")


demo_new.head()
# Out:
# Loading Demo data:
#   (20, 6)
#   SubjectID  Sex  Grade  Age  IQ  Group
# 1     nnr26    2      3    9  28      3
# 2     nnr27    1      3   10  26      3
# 3     nnr33    1      1    7  24      3
# 4     nnr36    2      1    7  21      3
# 5     nnr41    2      2    9  30      3

# %%
print("Loading Fix data: ")
tmp_fix = pd.read_excel(data_sets_xls, 'fixations_test',)
tmp_fix = dd._remove_missing_data(df=tmp_fix)


tmp_fix.astype({
    "SubjectID": str,
    "Sentence_ID": int,
    "Word_Number": int,
    "FIX_X": float,
    "FIX_Y": float,
    "FIX_DURATION": float,
})



fix_new = tmp_fix.sort_values(by=["SubjectID", "Sentence_ID",]).dropna()

print(" ", fix_new.shape)
print(" ")


fix_new.head()





fix_demo_new = dd.concat_dfs(
            df1=fix_new,
            df2=demo_new,
            features1=fix_new.columns,
            features2=[
                "Sex", "Grade", "Age", "IQ", "Group",
            ],
        )

fix_demo_new
# Out:
# Loading Fix data:
#   (15916, 6)
#     SubjectID  Sentence_ID  Word_Number   FIX_X  FIX_Y  FIX_DURATION  Sex  \
# 0       nnr26            4            1   145.9  542.1           499    2
# 1       nnr26            4            2   215.9  539.9           182    2
# 2       nnr26            4            3   275.7  551.1           185    2
# 3       nnr26            4            3   336.6  571.5           260    2
# 4       nnr26            4            4   344.1  545.2           221    2
# ..        ...          ...          ...     ...    ...           ...  ...
# 435     nnr85           33            4   544.3  499.9           183    1
# 436     nnr85           33            5   845.9  521.2           174    1
# 437     nnr85           33            5   738.6  522.4           283    1
# 438     nnr85           33            5   793.2  516.8           185    1
# 439     nnr85           33            6  1029.0  521.3           225    1
#
#      Grade  Age  IQ  Group
# ...

# %%
# # Artificially add rows with missing grades or gender to handle missing values during dummy conversion

# gender_diff = set(df_data_to_use.Sex).difference(set(fix_demo_new.Sex))

# grade_diff = set(df_data_to_use.Grade).difference(set(fix_demo_new.Grade))


# for d in grade_diff:
#     a_row = df_data_to_use.loc[df_data_to_use.Grade == d].iloc[0, :]
    
#     fix_demo_new.loc[-1] = a_row
#     fix_demo_new.index = fix_demo_new.index + 1  # shifting index

    


    
# for g in gender_diff:
#     a_row = df_data_to_use.loc[df_data_to_use.Sex == g].iloc[0, :]
    
#     fix_demo_new.loc[-1] = a_row
#     fix_demo_new.index = fix_demo_new.index + 1  # shifting index




# grade_diff

# %%
# indicators = ["SubjectID", "Sentence_ID", "Word_Number", ]

# fix_demo_new_dum = pd.get_dummies(data=fix_demo_new, columns=c_features)





# fix_demo_new_dum

# %%
# # Remove the the last two rows added synthetically to handle missing 5th and 6th grades.
# n_index = len(gender_diff) + len(grade_diff)

# # x_dum_test = fix_stats_demo_new_dum.drop(fix_stats_demo_new_dum.index[-n_index:])
# x_dum_test = fix_demo_new_dum.drop(fix_demo_new_dum.index[-n_index:])
    
# x_dum_test

# %%
_ = dd.get_demo_datasets()  # demos and phonological (which is initially part of demo)
demo_phono = dd.concat_classes_demo()

# The optimize way to exclude at-risk class
if to_exclude_at_risk == 1:
    to_exclude_at_risk = True
    demo_phono = demo_phono.loc[demo_phono.Group != 2]

demo_old = demo_phono.loc[:, [
    'Group', 'SubjectID', 'Sex', 'Grade', 'Age', 'IQ', 'Reading_speed',
]]

c_features = ['Sex', 'Grade', ]
# Out:
# Loading Demo data:
#   dyslexia (72, 9)
#   norm (213, 9)
#   risk (22, 9)

# %%
demo_old_norm = demo_old.loc[demo_old.Group == 1]
demo_old_risk = demo_old.loc[demo_old.Group == 2]
demo_old_dys  = demo_old.loc[demo_old.Group == 3]


demo_new_norm = demo_new.loc[demo_new.Group == 1]
demo_new_risk = demo_new.loc[demo_new.Group == 2]
demo_new_dys  = demo_new.loc[demo_new.Group == 3]

# %% [markdown]
# # Data sets comparison

# %%
old_demo_stats = [213, 22, 72, ]
new_demo_stats = [demo_new_norm.shape[0], demo_new_risk.shape[0], demo_new_dys.shape[0], ]


fig = plt.figure(figsize=(19, 13))


ax = fig.add_subplot(1, 2, 1)  # 2 datasets
patches, texts, autotexts = ax.pie(
    x=old_demo_stats, 
    labels=['Normal', 'At-risk', 'Dyslexic'], 
    autopct='%.2f', 
    textprops={'fontsize': 14}                                   
)
    
plt.title('Old Data', fontsize=20)


ax = fig.add_subplot(1, 2, 2)  # 2 datasets
patches, texts, autotexts = ax.pie(
    x=new_demo_stats, 
    labels=['Normal', 'At-risk', 'Dyslexic'], 
    autopct='%.2f', 
    textprops={'fontsize': 14}                                   
)

plt.title('New Data', fontsize=20)


plt.show()

# %%
genders = [1, 2]

genders_old      = [len(demo_old['Sex'].loc[demo_old['Sex']==f]) for f in genders]
genders_old_norm = [len(demo_old_norm['Sex'].loc[demo_old_norm['Sex']==f]) for f in [1, 2]]
genders_old_risk = [len(demo_old_risk['Sex'].loc[demo_old_risk['Sex']==f]) for f in [1, 2]]
genders_old_dys  = [len(demo_old_dys['Sex'].loc[demo_old_dys['Sex']==f]) for f in genders]


genders_new      = [len(demo_new['Sex'].loc[demo_new['Sex']==f]) for f in genders]
genders_new_norm = [len(demo_new_norm['Sex'].loc[demo_new_norm['Sex']==f]) for f in [1, 2]]
genders_new_risk = [len(demo_new_risk['Sex'].loc[demo_new_risk['Sex']==f]) for f in [1, 2]]
genders_new_dys  = [len(demo_new_dys['Sex'].loc[demo_new_dys['Sex']==f]) for f in genders]

# %%
fig = plt.figure(figsize=(19, 13))



ax = fig.add_subplot(1, 4, 1)  # 4 datasets
patches, texts, autotexts = ax.pie(
    x=genders_old, 
    labels=['Female', 'Male'], 
    autopct='%.2f', 
    textprops={'fontsize': 14}                                   
)
    
plt.title('Old Demo', fontsize=20)


ax = fig.add_subplot(1, 4, 2)  # 4 datasets
patches, texts, autotexts = ax.pie(
    x=genders_new, 
    labels=['Female', 'Male'], 
    autopct='%.2f', 
    textprops={'fontsize': 14}                                   
)


plt.title('New Demo', fontsize=20)



ax = fig.add_subplot(1, 4, 3)  # 4 datasets
patches, texts, autotexts = ax.pie(
    x=genders_old_dys, 
    labels=['Female', 'Male'], 
    autopct='%.2f', 
    textprops={'fontsize': 14}                                   
)


plt.title('Old Dyslexia', fontsize=20)


ax = fig.add_subplot(1, 4, 4)  # 4 datasets
patches, texts, autotexts = ax.pie(
    x=genders_new_dys, 
    labels=['Female', 'Male'], 
    autopct='%.2f', 
    textprops={'fontsize': 14}                                   
)

plt.title('New Dyslexia', fontsize=20)

plt.show()

# %%
fig = plt.figure(figsize=(19, 13))

ax = fig.add_subplot(1, 6, 1)  # 6 datasets
patches, texts, autotexts = ax.pie(
    x=genders_old_norm, 
    labels=['Female', 'Male'], 
    autopct='%.2f', 
    textprops={'fontsize': 14}                                   
)


plt.title('Old Norm', fontsize=20)


ax = fig.add_subplot(1, 6, 2)  # 6 datasets
patches, texts, autotexts = ax.pie(
    x=genders_new_norm, 
    labels=['Female', 'Male'], 
    autopct='%.2f', 
    textprops={'fontsize': 14}
)

plt.title('New Norm', fontsize=20)


ax = fig.add_subplot(1, 6, 3)  # 6 datasets
patches, texts, autotexts = ax.pie(
    x=genders_old_dys, 
    labels=['Female', 'Male'], 
    autopct='%.2f', 
    textprops={'fontsize': 14}                                   
)
    
plt.title('Old Dyslexia', fontsize=20)


ax = fig.add_subplot(1, 6, 4)  # 6 datasets
patches, texts, autotexts = ax.pie(
    x=genders_new_dys, 
    labels=['Female', 'Male'], 
    autopct='%.2f', 
    textprops={'fontsize': 14}                                   
)

plt.title('New Dyslexia', fontsize=20)

ax = fig.add_subplot(1, 6, 5)  # 6 datasets
patches, texts, autotexts = ax.pie(
    x=genders_old_risk, 
    labels=['Female', 'Male'], 
    autopct='%.2f', 
    textprops={'fontsize': 14}                                   
)


plt.title('Old Risk', fontsize=20)


ax = fig.add_subplot(1, 6, 6)  # 6 datasets
patches, texts, autotexts = ax.pie(
    x=genders_new_risk, 
    labels=['Female', 'Male'], 
    autopct='%.2f', 
    textprops={'fontsize': 14}                                   
)

plt.title('New Risk', fontsize=20)



plt.show()
# Out:
# normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False

# %%
grades = [1, 2, 3, 4, 5, 6]


grades_old      = [len(demo_old['Grade'].loc[demo_old['Grade']==f]) for f in grades]
grades_old_norm = [len(demo_old_norm['Grade'].loc[demo_old_norm['Grade']==f]) for f in grades]
grades_old_dys  = [len(demo_old_dys['Grade'].loc[demo_old_dys['Grade']==f]) for f in grades]




grades_new      = [len(demo_new['Grade'].loc[demo_new['Grade']==f]) for f in grades]
grades_new_norm = [len(demo_new_norm['Grade'].loc[demo_new_norm['Grade']==f]) for f in grades]
grades_new_dys  = [len(demo_new_dys['Grade'].loc[demo_new_dys['Grade']==f]) for f in grades]

# %%
fig = plt.figure(figsize=(25, 15))


ax = fig.add_subplot(1, 6, 1)  # 6 datasets
patches, texts, autotexts = ax.pie(
    x=grades_old, 
    labels=['1', '2', '3', '4', '5', '6'], 
    autopct='%.2f', 
    textprops={'fontsize': 14}                                   
)


plt.title('Old Grades', fontsize=20)

ax = fig.add_subplot(1, 6, 2)  # 6 datasets
patches, texts, autotexts = ax.pie(
    x=grades_new, 
    labels=['1', '2', '3', '4', '5', '6'], 
    autopct='%.2f', 
    textprops={'fontsize': 14}                                   
)


plt.title('New Grades', fontsize=20)


ax = fig.add_subplot(1, 6, 3)  # 6 datasets
patches, texts, autotexts = ax.pie(
    x=grades_old_norm, 
    labels=['1', '2', '3', '4', '5', '6'],
    autopct='%.2f', 
    textprops={'fontsize': 14}                                   
)


plt.title('Old Norm', fontsize=20)


ax = fig.add_subplot(1, 6, 4)  # 6 datasets
patches, texts, autotexts = ax.pie(
    x=grades_new_norm, 
    labels=['1', '2', '3', '4', '5', '6'], 
    autopct='%.2f', 
    textprops={'fontsize': 14}
)

plt.title('New Norm', fontsize=20)


ax = fig.add_subplot(1, 6, 5)  # 6 datasets
patches, texts, autotexts = ax.pie(
    x=grades_old_dys, 
    labels=['1', '2', '3', '4', '5', '6'], 
    autopct='%.2f', 
    textprops={'fontsize': 14}                                   
)
    
plt.title('Old Dyslexia', fontsize=20)


ax = fig.add_subplot(1, 6, 6)  # 6 datasets
patches, texts, autotexts = ax.pie(
    x=grades_new_dys, 
    labels=['1', '2', '3', '4', '5', '6'], 
    autopct='%.2f', 
    textprops={'fontsize': 14}                                   
)

plt.title('New Dyslexia', fontsize=20)



plt.show()

# %% [markdown]
# # Fixation data sets comparison

# %%
grade_1_old      = fix_demo.loc[fix_demo.Grade == 1]
grade_1_old_norm = grade_1_old.loc[grade_1_old.Group == 1]
grade_1_old_dys  = grade_1_old.loc[grade_1_old.Group == 3]


grade_2_old      = fix_demo.loc[fix_demo.Grade == 2]
grade_2_old_norm = grade_2_old.loc[grade_2_old.Group == 1]
grade_2_old_dys  = grade_2_old.loc[grade_2_old.Group == 3]

grade_3_old      = fix_demo.loc[fix_demo.Grade == 3]
grade_3_old_norm = grade_3_old.loc[grade_3_old.Group == 1]
grade_3_old_dys  = grade_3_old.loc[grade_3_old.Group == 3]


grade_4_old      = fix_demo.loc[fix_demo.Grade == 4]
grade_4_old_norm = grade_4_old.loc[grade_4_old.Group == 1]
grade_4_old_dys  = grade_4_old.loc[grade_4_old.Group == 3]

# %%
grade_1_new      = fix_demo_new.loc[fix_demo_new.Grade == 1]
grade_1_new_norm = grade_1_new.loc[grade_1_new.Group == 1]
grade_1_new_dys  = grade_1_new.loc[grade_1_new.Group == 3]


grade_2_new      = fix_demo_new.loc[fix_demo_new.Grade == 2]
grade_2_new_norm = grade_2_new.loc[grade_2_new.Group == 1]
grade_2_new_dys  = grade_2_new.loc[grade_2_new.Group == 3]


grade_3_new      = fix_demo_new.loc[fix_demo_new.Grade == 3]
grade_3_new_norm = grade_3_new.loc[grade_3_new.Group == 1]
grade_3_new_dys  = grade_3_new.loc[grade_3_new.Group == 3]


grade_4_new      = fix_demo_new.loc[fix_demo_new.Grade == 4]
grade_4_new_norm = grade_4_new.loc[grade_4_new.Group == 1]
grade_4_new_dys  = grade_4_new.loc[grade_4_new.Group == 3]

# %%
features_to_show = [
    "Sex", "Age", "IQ", "FIX_X", "FIX_Y", "FIX_DURATION",
]

features_to_show
# Out:
# ['Sex', 'Age', 'IQ', 'FIX_X', 'FIX_Y', 'FIX_DURATION']

# %%
g1_o_n = grade_1_old_norm.loc[:, features_to_show].describe()
g2_o_n = grade_2_old_norm.loc[:, features_to_show].describe()
g3_o_n = grade_3_old_norm.loc[:, features_to_show].describe()
g4_o_n = grade_4_old_norm.loc[:, features_to_show].describe()

# %%
g1_o_d = grade_1_old_dys.loc[:, features_to_show].describe()
g2_o_d = grade_2_old_dys.loc[:, features_to_show].describe()
g3_o_d = grade_3_old_dys.loc[:, features_to_show].describe()
g4_o_d = grade_4_old_dys.loc[:, features_to_show].describe()

# %%
g1_n_n = grade_1_new_norm.loc[:, features_to_show].describe()
g2_n_n = grade_2_new_norm.loc[:, features_to_show].describe()
g3_n_n = grade_3_new_norm.loc[:, features_to_show].describe()
g4_n_n = grade_4_new_norm.loc[:, features_to_show].describe()

# %%
g1_n_d = grade_1_new_dys.loc[:, features_to_show].describe()
g2_n_d = grade_2_new_dys.loc[:, features_to_show].describe()
g3_n_d = grade_3_new_dys.loc[:, features_to_show].describe()
g4_n_d = grade_4_new_dys.loc[:, features_to_show].describe()

# %% [markdown]
# ## Difference between old and new 3rd grade dyslexia

# %%
print(
    f"  FIX_X \t  ave \t   std        min \t  max \n" 
    
    f" G1 old nornmal : {g1_o_n.FIX_X[1]:.3f}   {g1_o_n.FIX_X[2]:.3f}   {g1_o_n.FIX_X[3]:.3f}   {g1_o_n.FIX_X[-1]:.3f} \n"
    f" G1 new nornmal : {g1_n_n.FIX_X[1]:.3f}   {g1_n_n.FIX_X[2]:.3f}   {g1_n_n.FIX_X[3]:.3f}   {g1_n_n.FIX_X[-1]:.3f} \n"
    f" G1 old dyslexia: {g1_o_d.FIX_X[1]:.3f}   {g1_o_d.FIX_X[2]:.3f}   {g1_o_d.FIX_X[3]:.3f}   {g1_o_d.FIX_X[-1]:.3f} \n"
    f" G1 new dyslexia: {g1_n_d.FIX_X[1]:.3f}   {g1_n_d.FIX_X[2]:.3f}   {g1_n_d.FIX_X[3]:.3f}   {g1_n_d.FIX_X[-1]:.3f} \n \n"
    
    f" G2 old nornmal : {g2_o_n.FIX_X[1]:.3f}   {g2_o_n.FIX_X[2]:.3f}   {g2_o_n.FIX_X[3]:.3f}   {g2_o_n.FIX_X[-1]:.3f} \n"
    f" G2 new nornmal : {g2_n_n.FIX_X[1]:.3f}   {g2_n_n.FIX_X[2]:.3f}   {g2_n_n.FIX_X[3]:.3f}   {g2_n_n.FIX_X[-1]:.3f} \n"
    f" G2 old dyslexia: {g2_o_d.FIX_X[1]:.3f}   {g2_o_d.FIX_X[2]:.3f}   {g2_o_d.FIX_X[3]:.3f}   {g2_o_d.FIX_X[-1]:.3f} \n"
    f" G2 new dyslexia: {g2_n_d.FIX_X[1]:.3f}   {g2_n_d.FIX_X[2]:.3f}   {g2_n_d.FIX_X[3]:.3f}   {g2_n_d.FIX_X[-1]:.3f} \n \n"

    f" G3 old nornmal : {g3_o_n.FIX_X[1]:.3f}   {g3_o_n.FIX_X[2]:.3f}   {g3_o_n.FIX_X[3]:.3f}   {g3_o_n.FIX_X[-1]:.3f} \n"
    f" G3 new nornmal : {g3_n_n.FIX_X[1]:.3f}   {g3_n_n.FIX_X[2]:.3f}   {g3_n_n.FIX_X[3]:.3f}   {g3_n_n.FIX_X[-1]:.3f} \n"
    f" G3 old dyslexia: {g3_o_d.FIX_X[1]:.3f}   {g3_o_d.FIX_X[2]:.3f}   {g3_o_d.FIX_X[3]:.3f}   {g3_o_d.FIX_X[-1]:.3f} \n"
    f" G3 new dyslexia: {g3_n_d.FIX_X[1]:.3f}   {g3_n_d.FIX_X[2]:.3f}   {g3_n_d.FIX_X[3]:.3f}   {g3_n_d.FIX_X[-1]:.3f} \n \n"

    f" G4 old nornmal : {g4_o_n.FIX_X[1]:.3f}   {g4_o_n.FIX_X[2]:.3f}   {g4_o_n.FIX_X[3]:.3f}   {g4_o_n.FIX_X[-1]:.3f} \n"
    f" G4 new nornmal : {g4_n_n.FIX_X[1]:.3f}   {g4_n_n.FIX_X[2]:.3f}   {g4_n_n.FIX_X[3]:.3f}   {g4_n_n.FIX_X[-1]:.3f} \n"
    f" G4 old dyslexia: {g4_o_d.FIX_X[1]:.3f}   {g4_o_d.FIX_X[2]:.3f}   {g4_o_d.FIX_X[3]:.3f}   {g4_o_d.FIX_X[-1]:.3f} \n"
    f" G4 new dyslexia: {g4_n_d.FIX_X[1]:.3f}   {g4_n_d.FIX_X[2]:.3f}   {g4_n_d.FIX_X[3]:.3f}   {g4_n_d.FIX_X[-1]:.3f} \n \n"

)
# Out:
#   FIX_X 	  ave 	   std        min 	  max
#  G1 old nornmal : 632.401   306.153   119.000   1468.200
#  G1 new nornmal : 612.825   302.043   121.200   1438.600
#  G1 old dyslexia: 632.213   297.713   119.100   1441.000
#  G1 new dyslexia: 632.239   306.734   125.100   1417.800
#
#  G2 old nornmal : 622.111   303.044   120.000   1469.100
#  G2 new nornmal : 554.916   298.361   121.700   1346.700
#  G2 old dyslexia: 614.101   301.687   119.100   1435.200
#  G2 new dyslexia: 631.281   303.012   127.600   1401.000
#
#  G3 old nornmal : 618.612   298.599   120.200   1419.400
#  G3 new nornmal : 595.779   300.330   120.800   1429.200
#  G3 old dyslexia: 625.939   303.669   120.000   1464.000
#  G3 new dyslexia: 608.205   294.909   125.800   1431.700
#
#  G4 old nornmal : 616.352   296.956   120.100   1450.900
#  G4 new nornmal : 606.586   304.272   132.800   1389.300
#  G4 old dyslexia: 612.178   301.627   119.200   1459.300
#  G4 new dyslexia: 597.037   297.858   129.900   1442.300

# %% [markdown]
# - Note the closness between ave. and stds of old_normal with new_normal and new_dyslexia
# - Note the difference between min new_normal with the rest (calibration or raw data preprocessing issue)

# %%
fig = plt.figure(figsize=(65, 25))


# grade 1
ax = fig.add_subplot(4, 4, 1)  # 4 datasets
sns.kdeplot(grade_1_old_norm.FIX_DURATION.values)
plt.title('Old 1st grade normals ', fontsize=20)


ax = fig.add_subplot(4, 4, 2)  # 4 datasets
sns.kdeplot(grade_1_old_dys.FIX_DURATION.values)
plt.title('Old 1st grade dyslexics ', fontsize=20)

ax = fig.add_subplot(4, 4, 3)  # 4 datasets
sns.kdeplot(grade_1_new_norm.FIX_DURATION.values)
plt.title('New 1st grade normals ', fontsize=20)


ax = fig.add_subplot(4, 4, 4)  # 4 datasets
sns.kdeplot(grade_1_new_dys.FIX_DURATION.values)
plt.title('New 1st grade dyslexicxs ', fontsize=20)



# grade 2
ax = fig.add_subplot(4, 4, 5)  # 4 datasets
sns.kdeplot(grade_2_old_norm.FIX_DURATION.values)
plt.title('Old 2nd grade normals ', fontsize=20)


ax = fig.add_subplot(4, 4, 6)  # 4 datasets
sns.kdeplot(grade_2_old_dys.FIX_DURATION.values)
plt.title('Old 2nd grade dyslexics ', fontsize=20)

ax = fig.add_subplot(4, 4, 7)  # 4 datasets
sns.kdeplot(grade_2_new_norm.FIX_DURATION.values)
plt.title('New 2nd grade normals ', fontsize=20)


ax = fig.add_subplot(4, 4, 8)  # 4 datasets
sns.kdeplot(grade_2_new_dys.FIX_DURATION.values)
plt.title('New 2nd grade dyslexicxs ', fontsize=20)



# grade 3
ax = fig.add_subplot(4, 4, 9)  # 4 datasets
sns.kdeplot(grade_3_old_norm.FIX_DURATION.values)
plt.title('Old 3rd grade normals ', fontsize=20)


ax = fig.add_subplot(4, 4, 10)  # 4 datasets
sns.kdeplot(grade_3_old_dys.FIX_DURATION.values)
plt.title('Old 3rd grade dyslexics ', fontsize=20)

ax = fig.add_subplot(4, 4, 11)  # 4 datasets
sns.kdeplot(grade_3_new_norm.FIX_DURATION.values)
plt.title('New 3rd grade normals ', fontsize=20)


ax = fig.add_subplot(4, 4, 12)  # 4 datasets
sns.kdeplot(grade_3_new_dys.FIX_DURATION.values)
plt.title('New 3rd grade dyslexicxs ', fontsize=20)

# grade 4
ax = fig.add_subplot(4, 4, 13)  # 4 datasets
sns.kdeplot(grade_4_old_norm.FIX_DURATION.values)
plt.title('Old 1st grade normals ', fontsize=20)


ax = fig.add_subplot(4, 4, 14)  # 4 datasets
sns.kdeplot(grade_4_old_dys.FIX_DURATION.values)
plt.title('Old 1st grade dyslexics ', fontsize=20)

ax = fig.add_subplot(4, 4, 15)  # 4 datasets
sns.kdeplot(grade_4_new_norm.FIX_DURATION.values)
plt.title('New 1st grade normals ', fontsize=20)


ax = fig.add_subplot(4, 4, 16)  # 4 datasets
sns.kdeplot(grade_4_new_dys.FIX_DURATION.values)
plt.title('New 1st grade dyslexicxs ', fontsize=20)




plt.show()

# %%
# ax = fig.add_subplot(1, 4, 1)  # 4 datasets
fig = plt.figure(figsize=(15, 7))


sns.kdeplot(grade_3_old_norm.FIX_X.values, color='g', alpha=.5, legend=True)
sns.kdeplot(grade_3_old_dys.FIX_X.values, color='r', alpha=.5, legend=True)
sns.kdeplot(grade_3_new_norm.FIX_X.values, color='b', alpha=.9, legend=True)
sns.kdeplot(grade_3_new_dys.FIX_X.values, color='m', alpha=.9, legend=True)
plt.legend(['OLd Norm', 'OLd Dysl', 'New Norm', 'New Dysl'])

plt.title("FIX_X")

plt.show()

# %%
print(
    f"  FIX_Y \t  ave \t   std        min \t  max \n" 
    
    f" G1 old nornmal : {g1_o_n.FIX_Y[1]:.3f}   {g1_o_n.FIX_Y[2]:.3f}   {g1_o_n.FIX_Y[3]:.3f}   {g1_o_n.FIX_Y[-1]:.3f} \n"
    f" G1 new nornmal : {g1_n_n.FIX_Y[1]:.3f}   {g1_n_n.FIX_Y[2]:.3f}   {g1_n_n.FIX_Y[3]:.3f}   {g1_n_n.FIX_Y[-1]:.3f} \n"
    f" G1 old dyslexia: {g1_o_d.FIX_Y[1]:.3f}   {g1_o_d.FIX_Y[2]:.3f}   {g1_o_d.FIX_Y[3]:.3f}   {g1_o_d.FIX_Y[-1]:.3f} \n"
    f" G1 new dyslexia: {g1_n_d.FIX_Y[1]:.3f}   {g1_n_d.FIX_Y[2]:.3f}   {g1_n_d.FIX_Y[3]:.3f}   {g1_n_d.FIX_Y[-1]:.3f} \n \n"
    
    f" G2 old nornmal : {g2_o_n.FIX_Y[1]:.3f}   {g2_o_n.FIX_Y[2]:.3f}   {g2_o_n.FIX_Y[3]:.3f}   {g2_o_n.FIX_Y[-1]:.3f} \n"
    f" G2 new nornmal : {g2_n_n.FIX_Y[1]:.3f}   {g2_n_n.FIX_Y[2]:.3f}   {g2_n_n.FIX_Y[3]:.3f}   {g2_n_n.FIX_Y[-1]:.3f} \n"
    f" G2 old dyslexia: {g2_o_d.FIX_Y[1]:.3f}   {g2_o_d.FIX_Y[2]:.3f}   {g2_o_d.FIX_Y[3]:.3f}   {g2_o_d.FIX_Y[-1]:.3f} \n"
    f" G2 new dyslexia: {g2_n_d.FIX_Y[1]:.3f}   {g2_n_d.FIX_Y[2]:.3f}   {g2_n_d.FIX_Y[3]:.3f}   {g2_n_d.FIX_Y[-1]:.3f} \n \n"

    f" G3 old nornmal : {g3_o_n.FIX_Y[1]:.3f}   {g3_o_n.FIX_Y[2]:.3f}   {g3_o_n.FIX_Y[3]:.3f}   {g3_o_n.FIX_Y[-1]:.3f} \n"
    f" G3 new nornmal : {g3_n_n.FIX_Y[1]:.3f}   {g3_n_n.FIX_Y[2]:.3f}   {g3_n_n.FIX_Y[3]:.3f}   {g3_n_n.FIX_Y[-1]:.3f} \n"
    f" G3 old dyslexia: {g3_o_d.FIX_Y[1]:.3f}   {g3_o_d.FIX_Y[2]:.3f}   {g3_o_d.FIX_Y[3]:.3f}   {g3_o_d.FIX_Y[-1]:.3f} \n"
    f" G3 new dyslexia: {g3_n_d.FIX_Y[1]:.3f}   {g3_n_d.FIX_Y[2]:.3f}   {g3_n_d.FIX_Y[3]:.3f}   {g3_n_d.FIX_Y[-1]:.3f} \n \n"

    f" G4 old nornmal : {g4_o_n.FIX_Y[1]:.3f}   {g4_o_n.FIX_Y[2]:.3f}   {g4_o_n.FIX_Y[3]:.3f}   {g4_o_n.FIX_Y[-1]:.3f} \n"
    f" G4 new nornmal : {g4_n_n.FIX_Y[1]:.3f}   {g4_n_n.FIX_Y[2]:.3f}   {g4_n_n.FIX_Y[3]:.3f}   {g4_n_n.FIX_Y[-1]:.3f} \n"
    f" G4 old dyslexia: {g4_o_d.FIX_Y[1]:.3f}   {g4_o_d.FIX_Y[2]:.3f}   {g4_o_d.FIX_Y[3]:.3f}   {g4_o_d.FIX_Y[-1]:.3f} \n"
    f" G4 new dyslexia: {g4_n_d.FIX_Y[1]:.3f}   {g4_n_d.FIX_Y[2]:.3f}   {g4_n_d.FIX_Y[3]:.3f}   {g4_n_d.FIX_Y[-1]:.3f} \n \n"

)
# Out:
#   FIX_Y 	  ave 	   std        min 	  max
#  G1 old nornmal : 542.804   28.484   332.200   728.200
#  G1 new nornmal : 538.012   22.177   401.700   717.300
#  G1 old dyslexia: 530.847   21.004   480.100   574.900
#  G1 new dyslexia: 537.261   23.496   404.100   718.700
#
#  G2 old nornmal : 533.907   24.131   330.700   715.200
#  G2 new nornmal : 535.412   18.021   456.100   728.700
#  G2 old dyslexia: 527.945   16.286   480.000   574.800
#  G2 new dyslexia: 537.175   26.405   466.600   713.200
#
#  G3 old nornmal : 538.655   27.045   333.300   725.100
#  G3 new nornmal : 528.603   24.693   385.400   671.400
#  G3 old dyslexia: 533.768   21.411   480.000   574.900
#  G3 new dyslexia: 552.730   21.076   403.500   678.000
#
#  G4 old nornmal : 529.224   22.306   334.000   730.200
#  G4 new nornmal : 518.202   15.386   484.900   604.700
#  G4 old dyslexia: 531.313   17.003   480.000   574.800
#  G4 new dyslexia: 536.406   18.551   462.900   665.600

# %% [markdown]
# - Note the almost identical ave. of old_normal and new_deslexia (with ~ similar stds)
#
# - Note the larger value of new_normal ave than others
#
# - Note the difference between min values of new_normal with old_normal
#
# - Note the difference between min values of new_dyslexia with old_dyslexia (calibration or raw data preprocessing issue)

# %%
fig = plt.figure(figsize=(65, 25))


# grade 1
ax = fig.add_subplot(4, 4, 1)  # 4 datasets
sns.kdeplot(grade_1_old_norm.FIX_Y.values)
plt.title('Old 1st grade normals ', fontsize=20)


ax = fig.add_subplot(4, 4, 2)  # 4 datasets
sns.kdeplot(grade_1_old_dys.FIX_Y.values)
plt.title('Old 1st grade dyslexics ', fontsize=20)

ax = fig.add_subplot(4, 4, 3)  # 4 datasets
sns.kdeplot(grade_1_new_norm.FIX_Y.values)
plt.title('New 1st grade normals ', fontsize=20)


ax = fig.add_subplot(4, 4, 4)  # 4 datasets
sns.kdeplot(grade_1_new_dys.FIX_Y.values)
plt.title('New 1st grade dyslexicxs ', fontsize=20)



# grade 2
ax = fig.add_subplot(4, 4, 5)  # 4 datasets
sns.kdeplot(grade_2_old_norm.FIX_Y.values)
plt.title('Old 2nd grade normals ', fontsize=20)


ax = fig.add_subplot(4, 4, 6)  # 4 datasets
sns.kdeplot(grade_2_old_dys.FIX_Y.values)
plt.title('Old 2nd grade dyslexics ', fontsize=20)

ax = fig.add_subplot(4, 4, 7)  # 4 datasets
sns.kdeplot(grade_2_new_norm.FIX_Y.values)
plt.title('New 2nd grade normals ', fontsize=20)


ax = fig.add_subplot(4, 4, 8)  # 4 datasets
sns.kdeplot(grade_2_new_dys.FIX_Y.values)
plt.title('New 2nd grade dyslexicxs ', fontsize=20)



# grade 3
ax = fig.add_subplot(4, 4, 9)  # 4 datasets
sns.kdeplot(grade_3_old_norm.FIX_Y.values)
plt.title('Old 3rd grade normals ', fontsize=20)


ax = fig.add_subplot(4, 4, 10)  # 4 datasets
sns.kdeplot(grade_3_old_dys.FIX_Y.values)
plt.title('Old 3rd grade dyslexics ', fontsize=20)

ax = fig.add_subplot(4, 4, 11)  # 4 datasets
sns.kdeplot(grade_3_new_norm.FIX_Y.values)
plt.title('New 3rd grade normals ', fontsize=20)


ax = fig.add_subplot(4, 4, 12)  # 4 datasets
sns.kdeplot(grade_3_new_dys.FIX_Y.values)
plt.title('New 3rd grade dyslexicxs ', fontsize=20)

# grade 4
ax = fig.add_subplot(4, 4, 13)  # 4 datasets
sns.kdeplot(grade_4_old_norm.FIX_Y.values)
plt.title('Old 1st grade normals ', fontsize=20)


ax = fig.add_subplot(4, 4, 14)  # 4 datasets
sns.kdeplot(grade_4_old_dys.FIX_Y.values)
plt.title('Old 1st grade dyslexics ', fontsize=20)

ax = fig.add_subplot(4, 4, 15)  # 4 datasets
sns.kdeplot(grade_4_new_norm.FIX_Y.values)
plt.title('New 1st grade normals ', fontsize=20)


ax = fig.add_subplot(4, 4, 16)  # 4 datasets
sns.kdeplot(grade_4_new_dys.FIX_Y.values)
plt.title('New 1st grade dyslexicxs ', fontsize=20)


plt.show()

# %%
# ax = fig.add_subplot(1, 4, 1)  # 4 datasets
fig = plt.figure(figsize=(15, 7))


sns.kdeplot(grade_3_old_norm.FIX_Y.values, color='g', alpha=.6, legend=True)
sns.kdeplot(grade_3_old_dys.FIX_Y.values, color='r', alpha=.6, legend=True)
sns.kdeplot(grade_3_new_norm.FIX_Y.values, color='b', alpha=.9, legend=True)
sns.kdeplot(grade_3_new_dys.FIX_Y.values, color='m', alpha=.9, legend=True)
plt.legend(['OLd Norm', 'OLd Dysl', 'New Norm', 'New Dysl'])

plt.title("FIX_Y")

plt.show()

# %%
print(
    f"  FIX_DURATION \t  ave \t   std        min \t  max \n" 
    
    f" G1 old nornmal : {g1_o_n.FIX_DURATION[1]:.3f}   {g1_o_n.FIX_DURATION[2]:.3f}   {g1_o_n.FIX_DURATION[3]:.3f}   {g1_o_n.FIX_DURATION[-1]:.3f} \n"
    f" G1 new nornmal : {g1_n_n.FIX_DURATION[1]:.3f}   {g1_n_n.FIX_DURATION[2]:.3f}   {g1_n_n.FIX_DURATION[3]:.3f}   {g1_n_n.FIX_DURATION[-1]:.3f} \n"
    f" G1 old dyslexia: {g1_o_d.FIX_DURATION[1]:.3f}   {g1_o_d.FIX_DURATION[2]:.3f}   {g1_o_d.FIX_DURATION[3]:.3f}   {g1_o_d.FIX_DURATION[-1]:.3f} \n"
    f" G1 new dyslexia: {g1_n_d.FIX_DURATION[1]:.3f}   {g1_n_d.FIX_DURATION[2]:.3f}   {g1_n_d.FIX_DURATION[3]:.3f}   {g1_n_d.FIX_DURATION[-1]:.3f} \n \n"
    
    f" G2 old nornmal : {g2_o_n.FIX_DURATION[1]:.3f}   {g2_o_n.FIX_DURATION[2]:.3f}   {g2_o_n.FIX_DURATION[3]:.3f}   {g2_o_n.FIX_DURATION[-1]:.3f} \n"
    f" G2 new nornmal : {g2_n_n.FIX_DURATION[1]:.3f}   {g2_n_n.FIX_DURATION[2]:.3f}   {g2_n_n.FIX_DURATION[3]:.3f}   {g2_n_n.FIX_DURATION[-1]:.3f} \n"
    f" G2 old dyslexia: {g2_o_d.FIX_DURATION[1]:.3f}   {g2_o_d.FIX_DURATION[2]:.3f}   {g2_o_d.FIX_DURATION[3]:.3f}   {g2_o_d.FIX_DURATION[-1]:.3f} \n"
    f" G2 new dyslexia: {g2_n_d.FIX_DURATION[1]:.3f}   {g2_n_d.FIX_DURATION[2]:.3f}   {g2_n_d.FIX_DURATION[3]:.3f}   {g2_n_d.FIX_DURATION[-1]:.3f} \n \n"

    f" G3 old nornmal : {g3_o_n.FIX_DURATION[1]:.3f}   {g3_o_n.FIX_DURATION[2]:.3f}   {g3_o_n.FIX_DURATION[3]:.3f}   {g3_o_n.FIX_DURATION[-1]:.3f} \n"
    f" G3 new nornmal : {g3_n_n.FIX_DURATION[1]:.3f}   {g3_n_n.FIX_DURATION[2]:.3f}   {g3_n_n.FIX_DURATION[3]:.3f}   {g3_n_n.FIX_DURATION[-1]:.3f} \n"
    f" G3 old dyslexia: {g3_o_d.FIX_DURATION[1]:.3f}   {g3_o_d.FIX_DURATION[2]:.3f}   {g3_o_d.FIX_DURATION[3]:.3f}   {g3_o_d.FIX_DURATION[-1]:.3f} \n"
    f" G3 new dyslexia: {g3_n_d.FIX_DURATION[1]:.3f}   {g3_n_d.FIX_DURATION[2]:.3f}   {g3_n_d.FIX_DURATION[3]:.3f}   {g3_n_d.FIX_DURATION[-1]:.3f} \n \n"

    f" G4 old nornmal : {g4_o_n.FIX_DURATION[1]:.3f}   {g4_o_n.FIX_DURATION[2]:.3f}   {g4_o_n.FIX_DURATION[3]:.3f}   {g4_o_n.FIX_DURATION[-1]:.3f} \n"
    f" G4 new nornmal : {g4_n_n.FIX_DURATION[1]:.3f}   {g4_n_n.FIX_DURATION[2]:.3f}   {g4_n_n.FIX_DURATION[3]:.3f}   {g4_n_n.FIX_DURATION[-1]:.3f} \n"
    f" G4 old dyslexia: {g4_o_d.FIX_DURATION[1]:.3f}   {g4_o_d.FIX_DURATION[2]:.3f}   {g4_o_d.FIX_DURATION[3]:.3f}   {g4_o_d.FIX_DURATION[-1]:.3f} \n"
    f" G4 new dyslexia: {g4_n_d.FIX_DURATION[1]:.3f}   {g4_n_d.FIX_DURATION[2]:.3f}   {g4_n_d.FIX_DURATION[3]:.3f}   {g4_n_d.FIX_DURATION[-1]:.3f} \n \n"

)
# Out:
#   FIX_DURATION 	  ave 	   std        min 	  max
#  G1 old nornmal : 283.005   251.335   1.000   9780.000
#  G1 new nornmal : 335.929   182.488   2.000   2647.000
#  G1 old dyslexia: 397.511   322.501   1.000   4148.000
#  G1 new dyslexia: 404.303   248.496   8.000   2686.000
#
#  G2 old nornmal : 249.410   167.712   1.000   2930.000
#  G2 new nornmal : 283.390   157.351   13.000   1396.000
#  G2 old dyslexia: 335.329   180.087   27.000   1621.000
#  G2 new dyslexia: 309.936   166.810   2.000   1438.000
#
#  G3 old nornmal : 221.306   140.807   1.000   4190.000
#  G3 new nornmal : 270.403   146.325   25.000   2051.000
#  G3 old dyslexia: 327.458   208.625   1.000   3344.000
#  G3 new dyslexia: 350.356   217.656   21.000   2036.000
#
#  G4 old nornmal : 207.883   118.869   1.000   1615.000
#  G4 new nornmal : 225.925   88.227   69.000   712.000
#  G4 old dyslexia: 319.258   206.441   1.000   3418.000
#  G4 new dyslexia: 258.681   135.379   12.000   1061.000

# %% [markdown]
# - Note the difference between the ave. of new_normal and old_normal: why people of the same grade and the same group should have such big difference? (IQ, and Age might be the reason, and this proves the necessecity of collecting larger data sets)
#
#     - g3_o_n.FIX_DURATION[1] - g3_n_n.FIX_DURATION[1] = -30.405388221939376
#
#
#
# - Similarly, difference between the ave. of new_dyslexia and old_dyslexia:
#
#     - g3_o_d.FIX_DURATION[1] - g3_n_d.FIX_DURATION[1] = 30.61605467996634
#
#
# - Old data: g3_o_n.FIX_DURATION[1] - g3_o_d.FIX_DURATION[1] = -106.15105043496175 while
# - New data: g3_n_n.FIX_DURATION[1] - g3_n_d.FIX_DURATION[1] = -45.12960753305603
#
# Do you see the difference?
#
#
# - Note the difference between min of new and old data fixation_duration

# %%
fig = plt.figure(figsize=(65, 25))


# grade 1
ax = fig.add_subplot(4, 4, 1)  # 4 datasets
sns.kdeplot(grade_1_old_norm.FIX_DURATION.values)
plt.title('Old 1st grade normals ', fontsize=20)


ax = fig.add_subplot(4, 4, 2)  # 4 datasets
sns.kdeplot(grade_1_old_dys.FIX_DURATION.values)
plt.title('Old 1st grade dyslexics ', fontsize=20)

ax = fig.add_subplot(4, 4, 3)  # 4 datasets
sns.kdeplot(grade_1_new_norm.FIX_DURATION.values)
plt.title('New 1st grade normals ', fontsize=20)


ax = fig.add_subplot(4, 4, 4)  # 4 datasets
sns.kdeplot(grade_1_new_dys.FIX_DURATION.values)
plt.title('New 1st grade dyslexicxs ', fontsize=20)



# grade 2
ax = fig.add_subplot(4, 4, 5)  # 4 datasets
sns.kdeplot(grade_2_old_norm.FIX_DURATION.values)
plt.title('Old 2nd grade normals ', fontsize=20)


ax = fig.add_subplot(4, 4, 6)  # 4 datasets
sns.kdeplot(grade_2_old_dys.FIX_DURATION.values)
plt.title('Old 2nd grade dyslexics ', fontsize=20)

ax = fig.add_subplot(4, 4, 7)  # 4 datasets
sns.kdeplot(grade_2_new_norm.FIX_DURATION.values)
plt.title('New 2nd grade normals ', fontsize=20)


ax = fig.add_subplot(4, 4, 8)  # 4 datasets
sns.kdeplot(grade_2_new_dys.FIX_DURATION.values)
plt.title('New 2nd grade dyslexicxs ', fontsize=20)



# grade 3
ax = fig.add_subplot(4, 4, 9)  # 4 datasets
sns.kdeplot(grade_3_old_norm.FIX_DURATION.values)
plt.title('Old 3rd grade normals ', fontsize=20)


ax = fig.add_subplot(4, 4, 10)  # 4 datasets
sns.kdeplot(grade_3_old_dys.FIX_DURATION.values)
plt.title('Old 3rd grade dyslexics ', fontsize=20)

ax = fig.add_subplot(4, 4, 11)  # 4 datasets
sns.kdeplot(grade_3_new_norm.FIX_DURATION.values)
plt.title('New 3rd grade normals ', fontsize=20)


ax = fig.add_subplot(4, 4, 12)  # 4 datasets
sns.kdeplot(grade_3_new_dys.FIX_DURATION.values)
plt.title('New 3rd grade dyslexicxs ', fontsize=20)

# grade 4
ax = fig.add_subplot(4, 4, 13)  # 4 datasets
sns.kdeplot(grade_4_old_norm.FIX_DURATION.values)
plt.title('Old 1st grade normals ', fontsize=20)


ax = fig.add_subplot(4, 4, 14)  # 4 datasets
sns.kdeplot(grade_4_old_dys.FIX_DURATION.values)
plt.title('Old 1st grade dyslexics ', fontsize=20)

ax = fig.add_subplot(4, 4, 15)  # 4 datasets
sns.kdeplot(grade_4_new_norm.FIX_DURATION.values)
plt.title('New 1st grade normals ', fontsize=20)


ax = fig.add_subplot(4, 4, 16)  # 4 datasets
sns.kdeplot(grade_4_new_dys.FIX_DURATION.values)
plt.title('New 1st grade dyslexicxs ', fontsize=20)




plt.show()

# %%
# ax = fig.add_subplot(1, 4, 1)  # 4 datasets
fig = plt.figure(figsize=(15, 7))


sns.kdeplot(grade_3_old_norm.FIX_DURATION.values, color='g', alpha=.5, legend=True)
sns.kdeplot(grade_3_old_dys.FIX_DURATION.values, color='r', alpha=.5, legend=True)
sns.kdeplot(grade_3_new_norm.FIX_DURATION.values, color='b', alpha=.9, legend=True)
sns.kdeplot(grade_3_new_dys.FIX_DURATION.values, color='m', alpha=.9, legend=True)
plt.legend(['OLd Norm', 'OLd Dysl', 'New Norm', 'New Dysl'])

plt.title("FIX_DURATION")

plt.show()

# %%
print(
    f"  IQ \t  ave \t   std        min \t  max \n"
    
    f" old nornmal : {g3_o_n.IQ[1]: .3f}   {g3_o_n.IQ[2]:.3f}   {g3_o_n.IQ[3]:.3f}   {g3_o_n.IQ[-1]:.3f} \n"
    f" new nornmal : {g3_n_n.IQ[1]: .3f}   {g3_n_n.IQ[2]:.3f}   {g3_n_n.IQ[3]:.3f}   {g3_n_n.IQ[-1]:.3f} \n"
    f" old dyslexia: {g3_o_d.IQ[1]: .3f}   {g3_o_d.IQ[2]:.3f}   {g3_o_d.IQ[3]:.3f}   {g3_o_d.IQ[-1]:.3f} \n"
    f" new dyslexia: {g3_n_d.IQ[1]: .3f}   {g3_n_d.IQ[2]:.3f}   {g3_n_d.IQ[3]:.3f}   {g3_n_d.IQ[-1]:.3f} \n"
)
# Out:
#   IQ 	  ave 	   std        min 	  max
#  old nornmal :  31.331   3.497   21.000   35.000
#  new nornmal :  31.221   2.679   28.000   35.000
#  old dyslexia:  32.015   5.172   15.000   36.000
#  new dyslexia:  26.080   1.101   25.000   28.000

# %%
fig = plt.figure(figsize=(20, 7))


ax = fig.add_subplot(1, 4, 1)  # 4 datasets
sns.kdeplot(grade_3_old_norm.IQ.values)
plt.title('Old 3rd grade normals ', fontsize=12)


ax = fig.add_subplot(1, 4, 2)  # 4 datasets
sns.kdeplot(grade_3_old_dys.IQ.values)
plt.title('Old 3rd grade dyslexics ', fontsize=12)

ax = fig.add_subplot(1, 4, 3)  # 4 datasets
sns.kdeplot(grade_3_new_norm.IQ.values)
plt.title('New 3rd grade normals ', fontsize=12)


ax = fig.add_subplot(1, 4, 4)  # 4 datasets
sns.kdeplot(grade_3_new_dys.IQ.values)
plt.title('New 3rd grade dyslexicx ', fontsize=12)


plt.show()

# %%
print(
    f"  Age \t  ave \t   std        min \t  max \n"
    
    f" old nornmal : {g3_o_n.Age[1]: .3f}   {g3_o_n.Age[2]:.3f}   {g3_o_n.Age[3]:.3f}   {g3_o_n.Age[-1]:.3f} \n"
    f" new nornmal : {g3_n_n.Age[1]: .3f}   {g3_n_n.Age[2]:.3f}   {g3_n_n.Age[3]:.3f}   {g3_n_n.Age[-1]:.3f} \n"
    f" old dyslexia: {g3_o_d.Age[1]: .3f}   {g3_o_d.Age[2]:.3f}   {g3_o_d.Age[3]:.3f}   {g3_o_d.Age[-1]:.3f} \n"
    f" new dyslexia: {g3_n_d.Age[1]: .3f}   {g3_n_d.Age[2]:.3f}   {g3_n_d.Age[3]:.3f}   {g3_n_d.Age[-1]:.3f} \n"
)
# Out:
#   Age 	  ave 	   std        min 	  max
#  old nornmal :  9.266   0.442   9.000   10.000
#  new nornmal :  9.417   0.493   9.000   10.000
#  old dyslexia:  9.258   0.543   8.000   10.000
#  new dyslexia:  9.431   0.495   9.000   10.000

# %% [markdown]
# - New normals age is similar to grade 2 rather than grade 3;
#
# - More so, ave of old_normals for this grade was 9.3 ± 0.442 while ave of new_nornmals is nor  8.886  ± 0.318
#
# - These are indeed missing and new data, expecting any ML method with the current data set size to generize such unseen data points is indeed unrealistic

# %%
fig = plt.figure(figsize=(20, 7))


ax = fig.add_subplot(1, 4, 1)  # 4 datasets
sns.kdeplot(grade_3_old_norm.Age.values)
plt.title('Old 3rd grade normals ', fontsize=12)


ax = fig.add_subplot(1, 4, 2)  # 4 datasets
sns.kdeplot(grade_3_old_dys.Age.values)
plt.title('Old 3rd grade dyslexics ', fontsize=12)

ax = fig.add_subplot(1, 4, 3)  # 4 datasets
sns.kdeplot(grade_3_new_norm.Age.values)
plt.title('New 3rd grade normals ', fontsize=12)


ax = fig.add_subplot(1, 4, 4)  # 4 datasets
sns.kdeplot(grade_3_new_dys.Age.values)
plt.title('New 3rd grade dyslexicx ', fontsize=12)


plt.show()
