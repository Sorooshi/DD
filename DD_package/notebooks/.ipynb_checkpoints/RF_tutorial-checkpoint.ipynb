# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from types import SimpleNamespace 
from sklearn.ensemble import RandomForestClassifier

# %%
d = {"height": [1.60, 1.75, 1.85, 1.62, 1.65, 1.75],
    "weight": [82, 75, 85, 62, 55, 60], 
     "sex": [1, 1, 1, 2, 2, 2],
    }
d
# Out:
# {'height': [1.6, 1.75, 1.85, 1.62, 1.65, 1.75],
#  'weight': [82, 75, 85, 62, 55, 60],
#  'sex': [1, 1, 1, 2, 2, 2]}

# %%
data = pd.DataFrame(data=d)
data
# Out:
#    height  weight  sex
# 0    1.60      82    1
# 1    1.75      75    1
# 2    1.85      85    1
# 3    1.62      62    2
# 4    1.65      55    2
# 5    1.75      60    2

# %%
x = data.iloc[:, :2]
y = data.iloc[:, -1]

# %%
model = RandomForestClassifier(n_estimators=6, ).fit(x, y)

# %%
model.predict(x)
# Out:
# array([1, 1, 1, 2, 2, 2])

# %%
from sklearn import tree

fn=data.columns[:-1]
cn=["m", "f"]


fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=600)

tree.plot_tree(model.estimators_[0],
               feature_names = fn, 
               class_names=cn,
               filled = True);

# fig.savefig('rf_individualtree.png')
