# %%
import os
import sys
import time
import numpy as np
import pandas as pd
import seaborn as sns
from pathlib import Path
import matplotlib.pyplot as plt 
from collections import defaultdict 
from types import SimpleNamespace

# %%
sys.path.append("../")

from dd_package.data.dyslexia_data import DyslexiaData
from dd_package.data.preprocess import preprocess_data

from dd_package.models.regression_estimators import RegressionEstimators
from dd_package.models.classification_estimators import ClassificationEstimators

from dd_package.common.utils import save_a_dict, load_a_dict, print_the_evaluated_results

# %%
tmp = load_a_dict(name="dd_ia_demo_phono-rf_reg--shuffled:True--exclude at risk:0", 
                  save_path="../../Results/")

# %%
print_the_evaluated_results(results=tmp, learning_method="regression")
# Out:
#    mae     rmse  	 mrae 	 r2_score  	 meape  	 jsd
#  Ave   std  Ave   std   Ave   std   Ave   std   Ave   std   Ave   std
# 0.426 0.033 1.814 0.284 0.006 0.000 0.997 0.001 0.050 0.019 0.008 0.001

# %%
configs = {
    "models_path": Path("/home/soroosh/Programmes/DD/Models"),
    "results_path": Path("/home/soroosh/Programmes/DD/Results"),
    "figures_path": Path("/home/soroosh/Programmes/DD/Figures"),
    "params_path": Path("/home/soroosh/Programmes/DD//Params"),
    "n_repeats": 10,
    "n_splits": 5,
}

configs = SimpleNamespace(**configs)

estimator_name = "SV_cls"
data_name = "DD_demo"
to_shuffle = True
learning_method = "classification"

specifier = data_name+"-"+estimator_name+"-"+str(to_shuffle)
configs.specifier = specifier
configs.data_name = data_name
configs.name_wb = data_name+": "+specifier
configs.learning_method = learning_method
# configs.project = "DD_test"
# configs.group = "debug"

# %%
# res = load_a_dict(name="dd_demo-l_cls--shuffled:True--exclude at risk:0",
#                   save_path="/home/soroosh/Programmes/DD/Results/")


# print_the_evaluated_results(results=res, learning_method="classification")


# for k, v in res.items():
#     print("k:", k)
#     print("y_true:", v["y_test"])
#     print("y_pred:", v["y_pred"])
#     print(" ")

# %%
# from sklearn.preprocessing import OneHotEncoder

# enc = OneHotEncoder(sparse=False)
# y_true_ = v["y_test"].reshape(-1, 1)
# y_true_ = enc.fit_transform(y_true_)

# %%
dd = DyslexiaData(path="../../datasets/", n_repeats=5)



demos = dd.get_demo_datasets()
# Out:
# Loading Demo data:
#   dyslexia (72, 9)
#   norm (213, 9)
#   risk (22, 9)

# %%
demo = dd.concat_classes_demo()  # .reset_index(drop=True)

demo
# Out:
#      Group    SubjectID  Sex  Grade  Age  IQ  Reading_speed  Sound_detection  \
# 0        1           10    1      4   10  23          102.0         0.620000
# 1        1          108    1      4   10  34          139.0         1.000000
# 2        1           11    2      4   10  34          110.0         1.000000
# 3        1     11_norm1    1      2    9  28           71.0         0.950000
# 4        1     12_norm1    2      2    8  32           60.0         0.950000
# ..     ...          ...  ...    ...  ...  ..            ...              ...
# 212      1  varya_norm1    1      1    7  34           56.0         1.000000
# 68       3        vpa21    2      1    7  32           22.0         0.916667
# 69       3        yea20    1      3    9  34           20.0         0.875000
# 70       3        zaa15    1      3   10  31           78.0         0.958333
# 71       3        zrs09    2      3   10  32           97.0         0.956522
#
#      Sound_change
# 0        0.910000
# 1        0.950000
# 2        0.790000
# 3        0.910000
# 4        0.620000
# ..            ...
# 212      0.920000
# 68       0.916667
# 69       0.500000
# 70       0.916667
# 71       0.875000
#
# [307 rows x 9 columns]

# %%
# demo = demo.loc[demo.Group!=2]

# demo

# %%
# ia = dd.concat_classes_ia()  # .reset_index(drop=True)

# ia

# %%
# fix = dd.concat_classes_fix()  # .reset_index(drop=True)

# fix

# %%
# fix_demo = dd.concat_dfs(df1=fix,  
#                          df2=demo,
#                          features1=fix.columns, 
#                          features2=demo.columns[2:],
#                         )



# fix_demo

# %%
# ia_demo = dd.concat_dfs(df1=ia,  
#                         df2=demo,
#                         features1=ia.columns, 
#                         features2=demo.columns[2:],
#                         )

# ia_demo

# %%
x_org, y_org = dd.get_onehot_features_targets(
        data=demo,
        c_features= ["Sex", "Grade", ],  # 
        indicators=["SubjectID"],
    )

# %%
x = preprocess_data(x=x_org, pp='mm')  # only x is standardized
# Out:
# pre-processing: mm
# Preprocessed data shape: (307, 12)

# %%
import jax
import jax.numpy as jnp
from copy import deepcopy

# %%
c1 = x[1, :].reshape(1, -1)
c2 = x[52, :].reshape(1, -1)
c3 = x[111, :].reshape(1, -1)
centroids = jnp.concatenate((c1, c2, c3), axis=0)
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
def compute_euclidean(datapoint, centroid,):
    return jax.tree_leaves(jnp.sum(jnp.power(datapoint - centroid, 2), axis=1))[0]

def is_pos_def(x):
    return jax.tree_leaves(jnp.all(jnp.linalg.eigvals(x) > 0))

# %%
data = x

# %%
n_nodes = data.shape[0]
n_clusters = centroids.shape[0]
distance_fn = compute_euclidean

# %%
cv = dd.get_stratified_kfold_cv(
    to_shuffle=to_shuffle,
    n_splits=configs.n_splits,
)

# %%
y = y_org.Group.values



# y = preprocess_data(x=y, pp='mm')  # only x is standardized

# %%
f_iter = True 
n_iter = 0
n_iters = 400
tol_m = 1e-2
tol_g = 1e-3
clusters = jnp.zeros([n_nodes]) + jnp.inf

grads_sums = []
aris_history = []
grads_history = []
hessians_history = []


from sklearn import metrics


step_size = 2e-1
c_iter = 0


while f_iter: 
    
    # cluster assingment 
    for i in range(n_nodes):   
        distances = distance_fn(datapoint=x[i, :], centroid=centroids)
        clusters = clusters.at[i].set(jnp.argmin(distances, axis=0))
        
    previous_clusters = deepcopy(clusters)
    
    # cluster update
    tmp_grads, tmp_hess = [], []
    for k in range(n_clusters):
        
        cluster_data = jnp.mean(x[jnp.where(clusters==k)[0], :], axis=0).reshape(1, -1)
        
        # Gradient of the distance function w.r.t the closest center 
        grads = jax.jacfwd(distance_fn, argnums=(1,))(cluster_data, centroids[k, :])
        grads = jax.tree_leaves(grads)[0]
        
        # Upgate centrods
        updated_centeroid = centroids[k, :] - step_size * grads
        centroids = centroids.at[k].set(updated_centeroid[0])
        
        # Convergence check
        # FONC: First Order Necessary Condition
        l2_norm_grads= jnp.sqrt(jnp.sum(jnp.power(grads, 2)))
        tmp_grads.append(l2_norm_grads)

        # SONC: Second Order Necessary Condition
        # Jaccobian of gradients (hessian matrix) of the distance function w.r.t the closest center 
        hessian_mat = jax.hessian(distance_fn, argnums=(1,))(cluster_data, centroids[k, :])
        hessian_mat = jax.tree_leaves(hessian_mat)[0]
        if jnp.all(is_pos_def(hessian_mat[0])[0]):
            tmp_hess.append(1)
        else:
            tmp_hess.append(0)

    
    ave_l2_norms_grads = jnp.asarray(tmp_grads).mean()
    grads_history.append(ave_l2_norms_grads)
    
    ave_semi_pos_def_check = jnp.asarray(tmp_hess).mean()
    hessians_history.append(ave_semi_pos_def_check)
    
    ari = metrics.adjusted_rand_score(y, clusters)

    print(
        f"n_iter = {n_iter} ari={ari:.3f} f_iter={f_iter} ave_l2_norms_grads = {ave_l2_norms_grads:.3f}" 
    )
    
    
    # FOCN and SOCN    
    if ave_semi_pos_def_check ==1. and ave_l2_norms_grads <= tol_g:
        print("ave_l2_norms_grads:", ave_l2_norms_grads)
        print("An optimum has found! stoped by FONC and SONC")
        print("ARI:",ari)

        if jnp.all(previous_clusters == clusters):
            f_iter = False
            print("Converge by two consequitive cluster recovery results conincidence")            
            print(f"node {i} ARI {ari}")
            break
    
    n_iter += 1
    
    if n_iter >= n_iters:
        f_iter = False
# Out:
# n_iter = 0 ari=0.047 f_iter=True ave_l2_norms_grads = 1.774
# n_iter = 1 ari=0.048 f_iter=True ave_l2_norms_grads = 1.736
# n_iter = 2 ari=0.043 f_iter=True ave_l2_norms_grads = 1.701
# n_iter = 3 ari=0.040 f_iter=True ave_l2_norms_grads = 1.664
# n_iter = 4 ari=0.043 f_iter=True ave_l2_norms_grads = 1.625
# n_iter = 5 ari=0.037 f_iter=True ave_l2_norms_grads = 1.591
# n_iter = 6 ari=0.034 f_iter=True ave_l2_norms_grads = 1.556
# n_iter = 7 ari=0.032 f_iter=True ave_l2_norms_grads = 1.525
# n_iter = 8 ari=0.030 f_iter=True ave_l2_norms_grads = 1.488
# n_iter = 9 ari=0.030 f_iter=True ave_l2_norms_grads = 1.454
# n_iter = 10 ari=0.029 f_iter=True ave_l2_norms_grads = 1.418
# n_iter = 11 ari=0.026 f_iter=True ave_l2_norms_grads = 1.383
# n_iter = 12 ari=0.023 f_iter=True ave_l2_norms_grads = 1.346
# n_iter = 13 ari=0.018 f_iter=True ave_l2_norms_grads = 1.318
# n_iter = 14 ari=0.016 f_iter=True ave_l2_norms_grads = 1.292
# n_iter = 15 ari=0.014 f_iter=True ave_l2_norms_grads = 1.256
# n_iter = 16 ari=0.013 f_iter=True ave_l2_norms_grads = 1.227
# n_iter = 17 ari=0.013 f_iter=True ave_l2_norms_grads = 1.202
# n_iter = 18 ari=0.013 f_iter=True ave_l2_norms_grads = 1.178
# n_iter = 19 ari=0.013 f_iter=True ave_l2_norms_grads = 1.152
# n_iter = 20 ari=0.013 f_iter=True ave_l2_norms_grads = 1.128
# n_iter = 21 ari=0.013 f_iter=True ave_l2_norms_grads = 1.108
# n_iter = 22 ari=0.013 f_iter=True ave_l2_norms_grads = 1.076
# n_iter = 23 ari=0.013 f_iter=True ave_l2_norms_grads = 1.055
# n_iter = 24 ari=0.012 f_iter=True ave_l2_norms_grads = 1.034
# n_iter = 25 ari=0.013 f_iter=True ave_l2_norms_grads = 1.016
# n_iter = 26 ari=0.013 f_iter=True ave_l2_norms_grads = 0.996
# n_iter = 27 ari=0.013 f_iter=True ave_l2_norms_grads = 0.976
# n_iter = 28 ari=0.013 f_iter=True ave_l2_norms_grads = 0.956
# n_iter = 29 ari=0.013 f_iter=True ave_l2_norms_grads = 0.937
# n_iter = 30 ari=0.013 f_iter=True ave_l2_norms_grads = 0.918
# n_iter = 31 ari=0.013 f_iter=True ave_l2_norms_grads = 0.900
# n_iter = 32 ari=0.013 f_iter=True ave_l2_norms_grads = 0.882
# n_iter = 33 ari=0.013 f_iter=True ave_l2_norms_grads = 0.864
# n_iter = 34 ari=0.013 f_iter=True ave_l2_norms_grads = 0.847
# n_iter = 35 ari=0.013 f_iter=True ave_l2_norms_grads = 0.830
# n_iter = 36 ari=0.013 f_iter=True ave_l2_norms_grads = 0.813
# n_iter = 37 ari=0.013 f_iter=True ave_l2_norms_grads = 0.797
# n_iter = 38 ari=0.013 f_iter=True ave_l2_norms_grads = 0.781
# n_iter = 39 ari=0.013 f_iter=True ave_l2_norms_grads = 0.766
# n_iter = 40 ari=0.013 f_iter=True ave_l2_norms_grads = 0.750
# n_iter = 41 ari=0.013 f_iter=True ave_l2_norms_grads = 0.735
# n_iter = 42 ari=0.013 f_iter=True ave_l2_norms_grads = 0.721
# n_iter = 43 ari=0.013 f_iter=True ave_l2_norms_grads = 0.706
# n_iter = 44 ari=0.013 f_iter=True ave_l2_norms_grads = 0.692
# n_iter = 45 ari=0.013 f_iter=True ave_l2_norms_grads = 0.678
# n_iter = 46 ari=0.013 f_iter=True ave_l2_norms_grads = 0.665
# n_iter = 47 ari=0.013 f_iter=True ave_l2_norms_grads = 0.651
# n_iter = 48 ari=0.013 f_iter=True ave_l2_norms_grads = 0.638
# n_iter = 49 ari=0.013 f_iter=True ave_l2_norms_grads = 0.626
# n_iter = 50 ari=0.013 f_iter=True ave_l2_norms_grads = 0.613
# n_iter = 51 ari=0.013 f_iter=True ave_l2_norms_grads = 0.601
# n_iter = 52 ari=0.013 f_iter=True ave_l2_norms_grads = 0.589
# n_iter = 53 ari=0.013 f_iter=True ave_l2_norms_grads = 0.586
# n_iter = 54 ari=0.013 f_iter=True ave_l2_norms_grads = 0.574
# n_iter = 55 ari=0.013 f_iter=True ave_l2_norms_grads = 0.562
# n_iter = 56 ari=0.013 f_iter=True ave_l2_norms_grads = 0.551
# n_iter = 57 ari=0.013 f_iter=True ave_l2_norms_grads = 0.540
# n_iter = 58 ari=0.013 f_iter=True ave_l2_norms_grads = 0.529
# n_iter = 59 ari=0.013 f_iter=True ave_l2_norms_grads = 0.529
# n_iter = 60 ari=0.014 f_iter=True ave_l2_norms_grads = 0.523
# n_iter = 61 ari=0.014 f_iter=True ave_l2_norms_grads = 0.512
# n_iter = 62 ari=0.013 f_iter=True ave_l2_norms_grads = 0.511
# n_iter = 63 ari=0.013 f_iter=True ave_l2_norms_grads = 0.501
# n_iter = 64 ari=0.013 f_iter=True ave_l2_norms_grads = 0.491
# n_iter = 65 ari=0.013 f_iter=True ave_l2_norms_grads = 0.481
# n_iter = 66 ari=0.013 f_iter=True ave_l2_norms_grads = 0.471
# n_iter = 67 ari=0.014 f_iter=True ave_l2_norms_grads = 0.471
# n_iter = 68 ari=0.014 f_iter=True ave_l2_norms_grads = 0.462
# n_iter = 69 ari=0.015 f_iter=True ave_l2_norms_grads = 0.460
# n_iter = 70 ari=0.015 f_iter=True ave_l2_norms_grads = 0.451
# n_iter = 71 ari=0.015 f_iter=True ave_l2_norms_grads = 0.442
# n_iter = 72 ari=0.015 f_iter=True ave_l2_norms_grads = 0.433
# n_iter = 73 ari=0.017 f_iter=True ave_l2_norms_grads = 0.443
# n_iter = 74 ari=0.017 f_iter=True ave_l2_norms_grads = 0.434
# n_iter = 75 ari=0.017 f_iter=True ave_l2_norms_grads = 0.426
# n_iter = 76 ari=0.017 f_iter=True ave_l2_norms_grads = 0.417
# n_iter = 77 ari=0.017 f_iter=True ave_l2_norms_grads = 0.409
# n_iter = 78 ari=0.017 f_iter=True ave_l2_norms_grads = 0.401
# n_iter = 79 ari=0.017 f_iter=True ave_l2_norms_grads = 0.393
# n_iter = 80 ari=0.017 f_iter=True ave_l2_norms_grads = 0.385
# n_iter = 81 ari=0.017 f_iter=True ave_l2_norms_grads = 0.377
# n_iter = 82 ari=0.017 f_iter=True ave_l2_norms_grads = 0.369
# n_iter = 83 ari=0.017 f_iter=True ave_l2_norms_grads = 0.362
# n_iter = 84 ari=0.017 f_iter=True ave_l2_norms_grads = 0.355
# n_iter = 85 ari=0.017 f_iter=True ave_l2_norms_grads = 0.348
# n_iter = 86 ari=0.017 f_iter=True ave_l2_norms_grads = 0.341
# n_iter = 87 ari=0.017 f_iter=True ave_l2_norms_grads = 0.334
# n_iter = 88 ari=0.017 f_iter=True ave_l2_norms_grads = 0.327
# n_iter = 89 ari=0.017 f_iter=True ave_l2_norms_grads = 0.321
# n_iter = 90 ari=0.017 f_iter=True ave_l2_norms_grads = 0.314
# n_iter = 91 ari=0.017 f_iter=True ave_l2_norms_grads = 0.308
# n_iter = 92 ari=0.017 f_iter=True ave_l2_norms_grads = 0.302
# n_iter = 93 ari=0.018 f_iter=True ave_l2_norms_grads = 0.317
# n_iter = 94 ari=0.018 f_iter=True ave_l2_norms_grads = 0.311
# n_iter = 95 ari=0.018 f_iter=True ave_l2_norms_grads = 0.305
# n_iter = 96 ari=0.018 f_iter=True ave_l2_norms_grads = 0.312
# n_iter = 97 ari=0.018 f_iter=True ave_l2_norms_grads = 0.305
# n_iter = 98 ari=0.018 f_iter=True ave_l2_norms_grads = 0.299
# n_iter = 99 ari=0.018 f_iter=True ave_l2_norms_grads = 0.293
# n_iter = 100 ari=0.018 f_iter=True ave_l2_norms_grads = 0.287
# n_iter = 101 ari=0.017 f_iter=True ave_l2_norms_grads = 0.289
# n_iter = 102 ari=0.017 f_iter=True ave_l2_norms_grads = 0.284
# n_iter = 103 ari=0.017 f_iter=True ave_l2_norms_grads = 0.278
# n_iter = 104 ari=0.017 f_iter=True ave_l2_norms_grads = 0.272
# n_iter = 105 ari=0.017 f_iter=True ave_l2_norms_grads = 0.267
# n_iter = 106 ari=0.017 f_iter=True ave_l2_norms_grads = 0.262
# n_iter = 107 ari=0.017 f_iter=True ave_l2_norms_grads = 0.256
# n_iter = 108 ari=0.017 f_iter=True ave_l2_norms_grads = 0.251
# n_iter = 109 ari=0.017 f_iter=True ave_l2_norms_grads = 0.246
# n_iter = 110 ari=0.017 f_iter=True ave_l2_norms_grads = 0.241
# n_iter = 111 ari=0.017 f_iter=True ave_l2_norms_grads = 0.237
# n_iter = 112 ari=0.017 f_iter=True ave_l2_norms_grads = 0.232
# n_iter = 113 ari=0.017 f_iter=True ave_l2_norms_grads = 0.227
# n_iter = 114 ari=0.017 f_iter=True ave_l2_norms_grads = 0.223
# n_iter = 115 ari=0.017 f_iter=True ave_l2_norms_grads = 0.218
# n_iter = 116 ari=0.017 f_iter=True ave_l2_norms_grads = 0.214
# n_iter = 117 ari=0.017 f_iter=True ave_l2_norms_grads = 0.210
# n_iter = 118 ari=0.017 f_iter=True ave_l2_norms_grads = 0.205
# n_iter = 119 ari=0.017 f_iter=True ave_l2_norms_grads = 0.201
# n_iter = 120 ari=0.017 f_iter=True ave_l2_norms_grads = 0.197
# n_iter = 121 ari=0.017 f_iter=True ave_l2_norms_grads = 0.193
# n_iter = 122 ari=0.017 f_iter=True ave_l2_norms_grads = 0.189
# n_iter = 123 ari=0.017 f_iter=True ave_l2_norms_grads = 0.186
# n_iter = 124 ari=0.017 f_iter=True ave_l2_norms_grads = 0.182
# n_iter = 125 ari=0.017 f_iter=True ave_l2_norms_grads = 0.178
# n_iter = 126 ari=0.017 f_iter=True ave_l2_norms_grads = 0.175
# n_iter = 127 ari=0.017 f_iter=True ave_l2_norms_grads = 0.171
# n_iter = 128 ari=0.017 f_iter=True ave_l2_norms_grads = 0.168
# n_iter = 129 ari=0.017 f_iter=True ave_l2_norms_grads = 0.164
# n_iter = 130 ari=0.017 f_iter=True ave_l2_norms_grads = 0.161
# n_iter = 131 ari=0.017 f_iter=True ave_l2_norms_grads = 0.158
# n_iter = 132 ari=0.017 f_iter=True ave_l2_norms_grads = 0.155
# n_iter = 133 ari=0.017 f_iter=True ave_l2_norms_grads = 0.152
# n_iter = 134 ari=0.017 f_iter=True ave_l2_norms_grads = 0.149
# n_iter = 135 ari=0.017 f_iter=True ave_l2_norms_grads = 0.146
# n_iter = 136 ari=0.017 f_iter=True ave_l2_norms_grads = 0.143
# n_iter = 137 ari=0.017 f_iter=True ave_l2_norms_grads = 0.140
# n_iter = 138 ari=0.017 f_iter=True ave_l2_norms_grads = 0.137
# n_iter = 139 ari=0.017 f_iter=True ave_l2_norms_grads = 0.134
# n_iter = 140 ari=0.017 f_iter=True ave_l2_norms_grads = 0.132
# n_iter = 141 ari=0.017 f_iter=True ave_l2_norms_grads = 0.129
# n_iter = 142 ari=0.017 f_iter=True ave_l2_norms_grads = 0.126
# n_iter = 143 ari=0.017 f_iter=True ave_l2_norms_grads = 0.124
# n_iter = 144 ari=0.017 f_iter=True ave_l2_norms_grads = 0.121
# n_iter = 145 ari=0.017 f_iter=True ave_l2_norms_grads = 0.119
# n_iter = 146 ari=0.017 f_iter=True ave_l2_norms_grads = 0.117
# n_iter = 147 ari=0.017 f_iter=True ave_l2_norms_grads = 0.114
# n_iter = 148 ari=0.017 f_iter=True ave_l2_norms_grads = 0.112
# n_iter = 149 ari=0.017 f_iter=True ave_l2_norms_grads = 0.110
# n_iter = 150 ari=0.017 f_iter=True ave_l2_norms_grads = 0.108
# n_iter = 151 ari=0.017 f_iter=True ave_l2_norms_grads = 0.105
# n_iter = 152 ari=0.017 f_iter=True ave_l2_norms_grads = 0.103
# n_iter = 153 ari=0.017 f_iter=True ave_l2_norms_grads = 0.101
# n_iter = 154 ari=0.017 f_iter=True ave_l2_norms_grads = 0.099
# n_iter = 155 ari=0.017 f_iter=True ave_l2_norms_grads = 0.097
# n_iter = 156 ari=0.017 f_iter=True ave_l2_norms_grads = 0.095
# n_iter = 157 ari=0.017 f_iter=True ave_l2_norms_grads = 0.093
# n_iter = 158 ari=0.017 f_iter=True ave_l2_norms_grads = 0.092
# n_iter = 159 ari=0.017 f_iter=True ave_l2_norms_grads = 0.090
# n_iter = 160 ari=0.017 f_iter=True ave_l2_norms_grads = 0.088
# n_iter = 161 ari=0.017 f_iter=True ave_l2_norms_grads = 0.086
# n_iter = 162 ari=0.017 f_iter=True ave_l2_norms_grads = 0.084
# n_iter = 163 ari=0.017 f_iter=True ave_l2_norms_grads = 0.083
# n_iter = 164 ari=0.017 f_iter=True ave_l2_norms_grads = 0.081
# n_iter = 165 ari=0.017 f_iter=True ave_l2_norms_grads = 0.079
# n_iter = 166 ari=0.017 f_iter=True ave_l2_norms_grads = 0.078
# n_iter = 167 ari=0.017 f_iter=True ave_l2_norms_grads = 0.076
# n_iter = 168 ari=0.017 f_iter=True ave_l2_norms_grads = 0.075
# n_iter = 169 ari=0.017 f_iter=True ave_l2_norms_grads = 0.073
# n_iter = 170 ari=0.017 f_iter=True ave_l2_norms_grads = 0.072
# n_iter = 171 ari=0.017 f_iter=True ave_l2_norms_grads = 0.070
# n_iter = 172 ari=0.017 f_iter=True ave_l2_norms_grads = 0.069
# n_iter = 173 ari=0.017 f_iter=True ave_l2_norms_grads = 0.068
# n_iter = 174 ari=0.017 f_iter=True ave_l2_norms_grads = 0.066
# n_iter = 175 ari=0.017 f_iter=True ave_l2_norms_grads = 0.065
# n_iter = 176 ari=0.017 f_iter=True ave_l2_norms_grads = 0.064
# n_iter = 177 ari=0.017 f_iter=True ave_l2_norms_grads = 0.062
# n_iter = 178 ari=0.017 f_iter=True ave_l2_norms_grads = 0.061
# n_iter = 179 ari=0.017 f_iter=True ave_l2_norms_grads = 0.060
# n_iter = 180 ari=0.017 f_iter=True ave_l2_norms_grads = 0.059
# n_iter = 181 ari=0.017 f_iter=True ave_l2_norms_grads = 0.057
# n_iter = 182 ari=0.017 f_iter=True ave_l2_norms_grads = 0.056
# n_iter = 183 ari=0.017 f_iter=True ave_l2_norms_grads = 0.055
# n_iter = 184 ari=0.017 f_iter=True ave_l2_norms_grads = 0.054
# n_iter = 185 ari=0.017 f_iter=True ave_l2_norms_grads = 0.053
# n_iter = 186 ari=0.017 f_iter=True ave_l2_norms_grads = 0.052
# n_iter = 187 ari=0.017 f_iter=True ave_l2_norms_grads = 0.051
# n_iter = 188 ari=0.017 f_iter=True ave_l2_norms_grads = 0.050
# n_iter = 189 ari=0.017 f_iter=True ave_l2_norms_grads = 0.049
# n_iter = 190 ari=0.017 f_iter=True ave_l2_norms_grads = 0.048
# n_iter = 191 ari=0.017 f_iter=True ave_l2_norms_grads = 0.047
# n_iter = 192 ari=0.017 f_iter=True ave_l2_norms_grads = 0.046
# n_iter = 193 ari=0.017 f_iter=True ave_l2_norms_grads = 0.045
# n_iter = 194 ari=0.017 f_iter=True ave_l2_norms_grads = 0.044
# n_iter = 195 ari=0.017 f_iter=True ave_l2_norms_grads = 0.043
# n_iter = 196 ari=0.017 f_iter=True ave_l2_norms_grads = 0.042
# n_iter = 197 ari=0.017 f_iter=True ave_l2_norms_grads = 0.042
# n_iter = 198 ari=0.017 f_iter=True ave_l2_norms_grads = 0.041
# n_iter = 199 ari=0.017 f_iter=True ave_l2_norms_grads = 0.040
# n_iter = 200 ari=0.017 f_iter=True ave_l2_norms_grads = 0.039
# n_iter = 201 ari=0.017 f_iter=True ave_l2_norms_grads = 0.038
# n_iter = 202 ari=0.017 f_iter=True ave_l2_norms_grads = 0.038
# n_iter = 203 ari=0.017 f_iter=True ave_l2_norms_grads = 0.037
# n_iter = 204 ari=0.017 f_iter=True ave_l2_norms_grads = 0.036
# n_iter = 205 ari=0.017 f_iter=True ave_l2_norms_grads = 0.035
# n_iter = 206 ari=0.017 f_iter=True ave_l2_norms_grads = 0.035
# n_iter = 207 ari=0.017 f_iter=True ave_l2_norms_grads = 0.034
# n_iter = 208 ari=0.017 f_iter=True ave_l2_norms_grads = 0.033
# n_iter = 209 ari=0.017 f_iter=True ave_l2_norms_grads = 0.033
# n_iter = 210 ari=0.017 f_iter=True ave_l2_norms_grads = 0.032
# n_iter = 211 ari=0.017 f_iter=True ave_l2_norms_grads = 0.031
# n_iter = 212 ari=0.017 f_iter=True ave_l2_norms_grads = 0.031
# n_iter = 213 ari=0.017 f_iter=True ave_l2_norms_grads = 0.030
# n_iter = 214 ari=0.017 f_iter=True ave_l2_norms_grads = 0.030
# n_iter = 215 ari=0.017 f_iter=True ave_l2_norms_grads = 0.029
# n_iter = 216 ari=0.017 f_iter=True ave_l2_norms_grads = 0.028
# n_iter = 217 ari=0.017 f_iter=True ave_l2_norms_grads = 0.028
# n_iter = 218 ari=0.017 f_iter=True ave_l2_norms_grads = 0.027
# n_iter = 219 ari=0.017 f_iter=True ave_l2_norms_grads = 0.027
# n_iter = 220 ari=0.017 f_iter=True ave_l2_norms_grads = 0.026
# n_iter = 221 ari=0.017 f_iter=True ave_l2_norms_grads = 0.026
# n_iter = 222 ari=0.017 f_iter=True ave_l2_norms_grads = 0.025
# n_iter = 223 ari=0.017 f_iter=True ave_l2_norms_grads = 0.025
# n_iter = 224 ari=0.017 f_iter=True ave_l2_norms_grads = 0.024
# n_iter = 225 ari=0.017 f_iter=True ave_l2_norms_grads = 0.024
# n_iter = 226 ari=0.017 f_iter=True ave_l2_norms_grads = 0.023
# n_iter = 227 ari=0.017 f_iter=True ave_l2_norms_grads = 0.023
# n_iter = 228 ari=0.017 f_iter=True ave_l2_norms_grads = 0.022
# n_iter = 229 ari=0.017 f_iter=True ave_l2_norms_grads = 0.022
# n_iter = 230 ari=0.017 f_iter=True ave_l2_norms_grads = 0.021
# n_iter = 231 ari=0.017 f_iter=True ave_l2_norms_grads = 0.021
# n_iter = 232 ari=0.017 f_iter=True ave_l2_norms_grads = 0.021
# n_iter = 233 ari=0.017 f_iter=True ave_l2_norms_grads = 0.020
# n_iter = 234 ari=0.017 f_iter=True ave_l2_norms_grads = 0.020
# n_iter = 235 ari=0.017 f_iter=True ave_l2_norms_grads = 0.019
# n_iter = 236 ari=0.017 f_iter=True ave_l2_norms_grads = 0.019
# n_iter = 237 ari=0.017 f_iter=True ave_l2_norms_grads = 0.019
# n_iter = 238 ari=0.017 f_iter=True ave_l2_norms_grads = 0.018
# n_iter = 239 ari=0.017 f_iter=True ave_l2_norms_grads = 0.018
# n_iter = 240 ari=0.017 f_iter=True ave_l2_norms_grads = 0.017
# n_iter = 241 ari=0.017 f_iter=True ave_l2_norms_grads = 0.017
# n_iter = 242 ari=0.017 f_iter=True ave_l2_norms_grads = 0.017
# n_iter = 243 ari=0.017 f_iter=True ave_l2_norms_grads = 0.016
# n_iter = 244 ari=0.017 f_iter=True ave_l2_norms_grads = 0.016
# n_iter = 245 ari=0.017 f_iter=True ave_l2_norms_grads = 0.016
# n_iter = 246 ari=0.017 f_iter=True ave_l2_norms_grads = 0.015
# n_iter = 247 ari=0.017 f_iter=True ave_l2_norms_grads = 0.015
# n_iter = 248 ari=0.017 f_iter=True ave_l2_norms_grads = 0.015
# n_iter = 249 ari=0.017 f_iter=True ave_l2_norms_grads = 0.015
# n_iter = 250 ari=0.017 f_iter=True ave_l2_norms_grads = 0.014
# n_iter = 251 ari=0.017 f_iter=True ave_l2_norms_grads = 0.014
# n_iter = 252 ari=0.017 f_iter=True ave_l2_norms_grads = 0.014
# n_iter = 253 ari=0.017 f_iter=True ave_l2_norms_grads = 0.013
# n_iter = 254 ari=0.017 f_iter=True ave_l2_norms_grads = 0.013
# n_iter = 255 ari=0.017 f_iter=True ave_l2_norms_grads = 0.013
# n_iter = 256 ari=0.017 f_iter=True ave_l2_norms_grads = 0.013
# n_iter = 257 ari=0.017 f_iter=True ave_l2_norms_grads = 0.012
# n_iter = 258 ari=0.017 f_iter=True ave_l2_norms_grads = 0.012
# n_iter = 259 ari=0.017 f_iter=True ave_l2_norms_grads = 0.012
# n_iter = 260 ari=0.017 f_iter=True ave_l2_norms_grads = 0.012
# n_iter = 261 ari=0.017 f_iter=True ave_l2_norms_grads = 0.011
# n_iter = 262 ari=0.017 f_iter=True ave_l2_norms_grads = 0.011
# n_iter = 263 ari=0.017 f_iter=True ave_l2_norms_grads = 0.011
# n_iter = 264 ari=0.017 f_iter=True ave_l2_norms_grads = 0.011
# n_iter = 265 ari=0.017 f_iter=True ave_l2_norms_grads = 0.011
# n_iter = 266 ari=0.017 f_iter=True ave_l2_norms_grads = 0.010
# n_iter = 267 ari=0.017 f_iter=True ave_l2_norms_grads = 0.010
# n_iter = 268 ari=0.017 f_iter=True ave_l2_norms_grads = 0.010
# n_iter = 269 ari=0.017 f_iter=True ave_l2_norms_grads = 0.010
# n_iter = 270 ari=0.017 f_iter=True ave_l2_norms_grads = 0.010
# n_iter = 271 ari=0.017 f_iter=True ave_l2_norms_grads = 0.009
# n_iter = 272 ari=0.017 f_iter=True ave_l2_norms_grads = 0.009
# n_iter = 273 ari=0.017 f_iter=True ave_l2_norms_grads = 0.009
# n_iter = 274 ari=0.017 f_iter=True ave_l2_norms_grads = 0.009
# n_iter = 275 ari=0.017 f_iter=True ave_l2_norms_grads = 0.009
# n_iter = 276 ari=0.017 f_iter=True ave_l2_norms_grads = 0.008
# n_iter = 277 ari=0.017 f_iter=True ave_l2_norms_grads = 0.008
# n_iter = 278 ari=0.017 f_iter=True ave_l2_norms_grads = 0.008
# n_iter = 279 ari=0.017 f_iter=True ave_l2_norms_grads = 0.008
# n_iter = 280 ari=0.017 f_iter=True ave_l2_norms_grads = 0.008
# n_iter = 281 ari=0.017 f_iter=True ave_l2_norms_grads = 0.008
# n_iter = 282 ari=0.017 f_iter=True ave_l2_norms_grads = 0.007
# n_iter = 283 ari=0.017 f_iter=True ave_l2_norms_grads = 0.007
# n_iter = 284 ari=0.017 f_iter=True ave_l2_norms_grads = 0.007
# n_iter = 285 ari=0.017 f_iter=True ave_l2_norms_grads = 0.007
# n_iter = 286 ari=0.017 f_iter=True ave_l2_norms_grads = 0.007
# n_iter = 287 ari=0.017 f_iter=True ave_l2_norms_grads = 0.007
# n_iter = 288 ari=0.017 f_iter=True ave_l2_norms_grads = 0.007
# n_iter = 289 ari=0.017 f_iter=True ave_l2_norms_grads = 0.006
# n_iter = 290 ari=0.017 f_iter=True ave_l2_norms_grads = 0.006
# n_iter = 291 ari=0.017 f_iter=True ave_l2_norms_grads = 0.006
# n_iter = 292 ari=0.017 f_iter=True ave_l2_norms_grads = 0.006
# n_iter = 293 ari=0.017 f_iter=True ave_l2_norms_grads = 0.006
# n_iter = 294 ari=0.017 f_iter=True ave_l2_norms_grads = 0.006
# n_iter = 295 ari=0.017 f_iter=True ave_l2_norms_grads = 0.006
# n_iter = 296 ari=0.017 f_iter=True ave_l2_norms_grads = 0.006
# n_iter = 297 ari=0.017 f_iter=True ave_l2_norms_grads = 0.006
# n_iter = 298 ari=0.017 f_iter=True ave_l2_norms_grads = 0.005
# n_iter = 299 ari=0.017 f_iter=True ave_l2_norms_grads = 0.005
# n_iter = 300 ari=0.017 f_iter=True ave_l2_norms_grads = 0.005
# n_iter = 301 ari=0.017 f_iter=True ave_l2_norms_grads = 0.005
# n_iter = 302 ari=0.017 f_iter=True ave_l2_norms_grads = 0.005
# n_iter = 303 ari=0.017 f_iter=True ave_l2_norms_grads = 0.005
# n_iter = 304 ari=0.017 f_iter=True ave_l2_norms_grads = 0.005
# n_iter = 305 ari=0.017 f_iter=True ave_l2_norms_grads = 0.005
# n_iter = 306 ari=0.017 f_iter=True ave_l2_norms_grads = 0.005
# n_iter = 307 ari=0.017 f_iter=True ave_l2_norms_grads = 0.005
# n_iter = 308 ari=0.017 f_iter=True ave_l2_norms_grads = 0.004
# n_iter = 309 ari=0.017 f_iter=True ave_l2_norms_grads = 0.004
# n_iter = 310 ari=0.017 f_iter=True ave_l2_norms_grads = 0.004
# n_iter = 311 ari=0.017 f_iter=True ave_l2_norms_grads = 0.004

# %%
data = dd.get_stratified_train_test_splits(
    x=x, y=y,
    labels=y_org.Group.values,
    to_shuffle=to_shuffle,
    n_splits=configs.n_repeats
)

# %%
reg_est = ClassificationEstimators(
    x=x, y=y, cv=cv, data=data,
    estimator_name=estimator_name,
    configs=configs,
)

# %%
reg_est.instantiate_tuning_estimator_and_parameters()

# %%
reg_est.tune_hyper_parameters()

# %%
reg_est.instantiate_train_test_estimator()

# %%
reg_est.train_test_tuned_estimator()

# %%
# reg_est.save_params_results()

# %%
reg_est.print_results()

# %%
res = load_a_dict(name="DD_demo-L_cls-True_TEST",
                  save_path="/home/soroosh/Programmes/DD/Results/")


print_the_evaluated_results(results=res, learning_method="classification")

# %%
for k, v in res.items():
    print("probs:", v["y_pred_prob"])

# %%
to_exclude_at_risk = False

# dict of dicts, s.t each dict contains pd.df of a class, e.g normal
_ = dd.get_demo_datasets()  # demos and phonological (which is initially part of demo)
demo_phono = dd.concat_classes_demo()

# The optimize way to exclude at-risk class
if to_exclude_at_risk == 1:
    to_exclude_at_risk = True
    demo_phono = demo_phono.loc[demo_phono.Group != 2]

df_data_to_use = demo_phono.loc[:, [
                                       'Group', 'SubjectID', 'Sound_detection', 'Sound_change', 'Reading_speed'
                                   ]]
c_features = None
indicators = ['SubjectID', ]
targets = ["Group", "Reading_speed", ]

# %%
df_data_to_use

# %%
to_exclude_at_risk = True

# dict of dicts, s.t each dict contains pd.df of a class, e.g normal
_ = dd.get_demo_datasets()  # demos and phonological (which is initially part of demo)
demo_phono = dd.concat_classes_demo()

# The optimize way to exclude at-risk class
if to_exclude_at_risk == 1:
    to_exclude_at_risk = True
    demo_phono = demo_phono.loc[demo_phono.Group != 2]

df_data_to_use = demo_phono.loc[:, [
                                       'Group', 'SubjectID', 'Sound_detection', 'Sound_change', 'Reading_speed'
                                   ]]
c_features = None
indicators = ['SubjectID', ]
targets = ["Group", "Reading_speed", ]

# %%
df_data_to_use

# %%
set(df_data_to_use.Group)
